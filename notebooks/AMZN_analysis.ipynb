# %%
# Import scripts
import sys
sys.path.append('../scripts')
from prepare_data import load_and_prepare
from indicators import calculate_indicators
from visualize import plot_moving_averages, plot_rsi, plot_macd

# %%
# Load data
df = load_and_prepare("../data/AMZN.csv")  
print(df.head())
# Out:
#               Open    High     Low  Close     Volume
# Date
# 2009-01-02  2.5675  2.7265  2.5535  2.718  145928000
# 2009-01-05  2.7865  2.7870  2.6515  2.703  190196000
# 2009-01-06  2.7275  2.9110  2.6875  2.868  221602000
# 2009-01-07  2.8145  2.8475  2.7675  2.810  158854000
# 2009-01-08  2.7495  2.8660  2.7290  2.858  131558000

# %%
# Calculate indicators
df = calculate_indicators(df)
print(df.head())
# Out:
#               Open    High     Low  Close     Volume  SMA_20  EMA_20  RSI  \
# Date
# 2009-01-02  2.5675  2.7265  2.5535  2.718  145928000     NaN     NaN  NaN
# 2009-01-05  2.7865  2.7870  2.6515  2.703  190196000     NaN     NaN  NaN
# 2009-01-06  2.7275  2.9110  2.6875  2.868  221602000     NaN     NaN  NaN
# 2009-01-07  2.8145  2.8475  2.7675  2.810  158854000     NaN     NaN  NaN
# 2009-01-08  2.7495  2.8660  2.7290  2.858  131558000     NaN     NaN  NaN
#
#             MACD  MACD_signal  MACD_hist
# Date
# 2009-01-02   NaN          NaN        NaN
# 2009-01-05   NaN          NaN        NaN
# 2009-01-06   NaN          NaN        NaN
# 2009-01-07   NaN          NaN        NaN
# 2009-01-08   NaN          NaN        NaN

# %%
# Visualize
plot_moving_averages(df, "AMZN")
plot_rsi(df, "AMZN")
plot_macd(df, "AMZN")
