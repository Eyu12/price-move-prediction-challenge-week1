# %%
# Import scripts
import sys
sys.path.append('../scripts')   
from prepare_data import load_and_prepare
from indicators import calculate_indicators
from visualize import plot_moving_averages, plot_rsi, plot_macd

# %%
# Load data
df = load_and_prepare("../data/NVDA.csv")  
print(df.head())
# Out:
#                 Open      High       Low     Close      Volume
# Date
# 2009-01-02  0.184982  0.201027  0.184294  0.199652   497124000
# 2009-01-05  0.197360  0.207904  0.195984  0.203319   705736000
# 2009-01-06  0.209279  0.216156  0.204695  0.210196   657904000
# 2009-01-07  0.205382  0.205382  0.190483  0.197589   870096000
# 2009-01-08  0.195067  0.195067  0.180626  0.192546  1014496000

# %%
# Calculate indicators
df = calculate_indicators(df)
print(df.head())
# Out:
#                 Open      High       Low     Close      Volume  SMA_20  \
# Date
# 2009-01-02  0.184982  0.201027  0.184294  0.199652   497124000     NaN
# 2009-01-05  0.197360  0.207904  0.195984  0.203319   705736000     NaN
# 2009-01-06  0.209279  0.216156  0.204695  0.210196   657904000     NaN
# 2009-01-07  0.205382  0.205382  0.190483  0.197589   870096000     NaN
# 2009-01-08  0.195067  0.195067  0.180626  0.192546  1014496000     NaN
#
#             EMA_20  RSI  MACD  MACD_signal  MACD_hist
# Date
# 2009-01-02     NaN  NaN   NaN          NaN        NaN
# 2009-01-05     NaN  NaN   NaN          NaN        NaN
# 2009-01-06     NaN  NaN   NaN          NaN        NaN
# 2009-01-07     NaN  NaN   NaN          NaN        NaN
# 2009-01-08     NaN  NaN   NaN          NaN        NaN

# %%
# Visualize
plot_moving_averages(df, "NVDA")
plot_rsi(df, "NVDA")
plot_macd(df, "NVDA")
