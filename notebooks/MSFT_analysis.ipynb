# %%
# Import scripts
import sys
sys.path.append('../scripts')
from prepare_data import load_and_prepare
from indicators import calculate_indicators
from visualize import plot_moving_averages, plot_rsi, plot_macd

# %%
# Load data
df = load_and_prepare("../data/MSFT.csv")  
print(df.head())
# Out:
#                  Open       High        Low      Close    Volume
# Date
# 2009-01-02  14.287715  14.924187  14.170662  14.872976  50084000
# 2009-01-05  14.777866  15.121707  14.675444  15.011971  61475200
# 2009-01-06  15.180236  15.363130  15.077815  15.187551  58083400
# 2009-01-07  14.770560  14.843718  14.251139  14.273087  72709900
# 2009-01-08  14.360876  14.770561  14.302350  14.719351  70255400

# %%
# Calculate indicators
df = calculate_indicators(df)
print(df.head())
# Out:
#                  Open       High        Low      Close    Volume  SMA_20  \
# Date
# 2009-01-02  14.287715  14.924187  14.170662  14.872976  50084000     NaN
# 2009-01-05  14.777866  15.121707  14.675444  15.011971  61475200     NaN
# 2009-01-06  15.180236  15.363130  15.077815  15.187551  58083400     NaN
# 2009-01-07  14.770560  14.843718  14.251139  14.273087  72709900     NaN
# 2009-01-08  14.360876  14.770561  14.302350  14.719351  70255400     NaN
#
#             EMA_20  RSI  MACD  MACD_signal  MACD_hist
# Date
# 2009-01-02     NaN  NaN   NaN          NaN        NaN
# 2009-01-05     NaN  NaN   NaN          NaN        NaN
# 2009-01-06     NaN  NaN   NaN          NaN        NaN
# 2009-01-07     NaN  NaN   NaN          NaN        NaN
# 2009-01-08     NaN  NaN   NaN          NaN        NaN

# %%
# Visualize
plot_moving_averages(df, "MSFT")
plot_rsi(df, "MSFT")
plot_macd(df, "MSFT")
