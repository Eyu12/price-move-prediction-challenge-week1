# %%
# Import scripts
import sys
sys.path.append('../scripts')
from prepare_data import load_and_prepare
from indicators import calculate_indicators
from visualize import plot_moving_averages, plot_rsi, plot_macd

# %%
# Load data 
df = load_and_prepare("../data/GOOG.csv")  
print(df.head())
# Out:
#                 Open      High       Low     Close     Volume
# Date
# 2009-01-02  7.633949  7.960977  7.557264  7.948608  144961322
# 2009-01-05  7.940692  8.194003  7.792268  8.115089  196293007
# 2009-01-06  8.237046  8.430492  8.074027  8.263762  257971329
# 2009-01-07  8.121770  8.185839  7.885034  7.965677  180453860
# 2009-01-08  7.873406  8.044340  7.850152  8.044340  144567852

# %%
# Calculate indicators
df = calculate_indicators(df)
print(df.head())
# Out:
#                 Open      High       Low     Close     Volume  SMA_20  EMA_20  \
# Date
# 2009-01-02  7.633949  7.960977  7.557264  7.948608  144961322     NaN     NaN
# 2009-01-05  7.940692  8.194003  7.792268  8.115089  196293007     NaN     NaN
# 2009-01-06  8.237046  8.430492  8.074027  8.263762  257971329     NaN     NaN
# 2009-01-07  8.121770  8.185839  7.885034  7.965677  180453860     NaN     NaN
# 2009-01-08  7.873406  8.044340  7.850152  8.044340  144567852     NaN     NaN
#
#             RSI  MACD  MACD_signal  MACD_hist
# Date
# 2009-01-02  NaN   NaN          NaN        NaN
# 2009-01-05  NaN   NaN          NaN        NaN
# 2009-01-06  NaN   NaN          NaN        NaN
# 2009-01-07  NaN   NaN          NaN        NaN
# 2009-01-08  NaN   NaN          NaN        NaN

# %%
# Visualize
plot_moving_averages(df, "GOOG")
plot_rsi(df, "GOOG")
plot_macd(df, "GOOG")
