# %%
# Import scripts
import sys
sys.path.append('../scripts')
from prepare_data import load_and_prepare
from indicators import calculate_indicators
from visualize import plot_moving_averages, plot_rsi, plot_macd

# %%
# Load data
df = load_and_prepare("../data/AAPL.csv")  
print(df.head())
# Out:
#                 Open      High       Low     Close      Volume
# Date
# 2009-01-02  2.575630  2.730385  2.554037  2.721686   746015200
# 2009-01-05  2.794266  2.884539  2.780469  2.836553  1181608400
# 2009-01-06  2.877641  2.914229  2.770872  2.789767  1289310400
# 2009-01-07  2.753477  2.774170  2.706990  2.729484   753048800
# 2009-01-08  2.712090  2.793666  2.700393  2.780169   673500800

# %%
# Calculate indicators
df = calculate_indicators(df)
print(df.head())
# Out:
#                 Open      High       Low     Close      Volume  SMA_20  \
# Date
# 2009-01-02  2.575630  2.730385  2.554037  2.721686   746015200     NaN
# 2009-01-05  2.794266  2.884539  2.780469  2.836553  1181608400     NaN
# 2009-01-06  2.877641  2.914229  2.770872  2.789767  1289310400     NaN
# 2009-01-07  2.753477  2.774170  2.706990  2.729484   753048800     NaN
# 2009-01-08  2.712090  2.793666  2.700393  2.780169   673500800     NaN
#
#             EMA_20  RSI  MACD  MACD_signal  MACD_hist
# Date
# 2009-01-02     NaN  NaN   NaN          NaN        NaN
# 2009-01-05     NaN  NaN   NaN          NaN        NaN
# 2009-01-06     NaN  NaN   NaN          NaN        NaN
# 2009-01-07     NaN  NaN   NaN          NaN        NaN
# 2009-01-08     NaN  NaN   NaN          NaN        NaN

# %%
# Visualize
plot_moving_averages(df, "AAPL")
plot_rsi(df, "AAPL")
plot_macd(df, "AAPL")
