# %%
# Import scripts
import sys
sys.path.append('../scripts')
from prepare_data import load_and_prepare
from indicators import calculate_indicators
from visualize import plot_moving_averages, plot_rsi, plot_macd

# %%
# Load data 
df = load_and_prepare("../data/META.csv")
print(df.head())
# Out:
#                  Open       High        Low      Close     Volume
# Date
# 2012-05-18  41.792356  44.724282  37.767172  37.995762  573576400
# 2012-05-21  36.306177  36.435382  32.797807  33.821495  168192700
# 2012-05-22  32.410203  33.384198  30.750434  30.810066  101786600
# 2012-05-23  31.177799  32.300874  31.167860  31.803938   73600000
# 2012-05-24  32.748117  33.006523  31.575347  32.827625   50237200

# %%
# Calculate indicators
df = calculate_indicators(df)
print(df.head())
# Out:
#                  Open       High        Low      Close     Volume  SMA_20  \
# Date
# 2012-05-18  41.792356  44.724282  37.767172  37.995762  573576400     NaN
# 2012-05-21  36.306177  36.435382  32.797807  33.821495  168192700     NaN
# 2012-05-22  32.410203  33.384198  30.750434  30.810066  101786600     NaN
# 2012-05-23  31.177799  32.300874  31.167860  31.803938   73600000     NaN
# 2012-05-24  32.748117  33.006523  31.575347  32.827625   50237200     NaN
#
#             EMA_20  RSI  MACD  MACD_signal  MACD_hist
# Date
# 2012-05-18     NaN  NaN   NaN          NaN        NaN
# 2012-05-21     NaN  NaN   NaN          NaN        NaN
# 2012-05-22     NaN  NaN   NaN          NaN        NaN
# 2012-05-23     NaN  NaN   NaN          NaN        NaN
# 2012-05-24     NaN  NaN   NaN          NaN        NaN

# %%
# Visualize
plot_moving_averages(df, "META")
plot_rsi(df, "META")
plot_macd(df, "META")
